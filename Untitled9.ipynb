# %%
import pandas as pd
import numpy as np
data=pd.read_csv('C://Users//asus//Downloads//titanic-passengers.csv',encoding = "ISO-8859-1", delimiter = ";")
data.head()
data.tail()
data.describe()
data.isnull().sum()
data.drop(columns=['Cabin'], inplace = True)
data['Age'].fillna(df['Age'].mean(),inplace=True)
number_of_elements = len(data['Embarked'])
print("Number of elements: ", number_of_elements)
print(data['Embarked'].value_counts())
data['Embarked'].isnull().sum()
data['Embarked'].fillna("S", inplace = True)
import seaborn as sns
sns.countplot(df['Survived'])
sns.countplot(df['Sex'])
sns.distplot(df['Age'], bins=10,kde=False)
g= sns.FacetGrid(df, 'Survived')
g.map(sns.swarmplot, x=df['Sex'],y=df['Age'])
g.add_legend()
g= sns.FacetGrid(df, 'Survived')
g.map(sns.swarmplot, x=df['Cabin'],y=df['Pclass'])
g.add_legend()
import matplotlib.pyplot as plt
def plot_correlation_map( df ):

    corr = df.corr()

    s , ax = plt.subplots( figsize =( 12 , 10 ) )

    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )

    s = sns.heatmap(

        corr, 

        cmap = cmap,

        square=True, 

        cbar_kws={ 'shrink' : .9 }, 

        ax=ax, 

        annot = True, 

        annot_kws = { 'fontsize' : 12 }

        )
plot_correlation_map( df )
data["Title"]='Nan'
for i in range (data.shape[0]):
    ch =  data["Name"][i]
    j = ch.index(",")
    data["Title"][i] = ch[0:j]
data.head()
"Title" ={         "Capt":       "Officer",
                    "Col":        "Officer",
                    "Major":      "Officer",
                      "Dr":         "Officer",
                    "Rev":        "Officer",
                    "Jonkheer":   "Royalty",
                    "Don":        "Royalty",
                    "Sir" :       "Royalty",
                   "Lady" :      "Royalty",
                  "the Countess": "Royalty",
                    "Dona":       "Royalty",
                    "Mme":        "Miss",
                    "Mlle":       "Miss",
                    "Miss" :      "Miss",
                    "Ms":         "Mrs",
                    "Mr" :        "Mrs",
                    "Mrs" :       "Mrs",
                    "Master" :    "Master"
                   }
data.head()
g= sns.FacetGrid(df, 'Title')
g.map(sns.swarmplot, x=data['sex'],y=data['age'])
g.add_legend()
df["family size"]=df["SibSp"]+" "+df["Parch"]
df["survived"].plt.box()
g=sns.FacetGrid(df,col='survived')
g=sns.FacetGrid(df,col='family size')
g.add_legend()

# %% [raw]
# family size is not an important feature
